# %%
class Parent:
   def func1(self):
      print("this function is in parent class.") 
class Child(Parent):
    def func2(self):
      print("this function is in child class.")
object=Child()
object.func1()
object.func2()
# Out:
# this function is in parent class.
# this function is in chlid class.

# %%
class Parent:
    def func1(self):
        print("this class belongs to parent class")
class Chlid:
    def func1(self):
        print("this class belongs to child class")
object=Chlid()
object.func1()
# Out:
# this class belongs to child class
