# %%
import pandas as pd
order=pd.Series(["Deliverd","Cancelled","Shipped","Pending"])
print(order.dtype)
# Out:
# object

# %%
order=order.astype("category")
print(order.dtype)
# Out:
# category

# %%
salary=[1000,2000,3000,4000]
new_salary=[]
for s in salary:              
    new_salary.append(s*1.1)
print(new_salary)
# Out:
# [1100.0, 2200.0, 3300.0000000000005, 4400.0]

# %%
import numpy as np
salary=np.array([12000,130000,150000,340000])    #VECTORIZATION
new_salary=salary*1.1
print(new_salary)
# Out:
# [ 13200. 143000. 165000. 374000.]

# %%
price=np.array([130000,140000,250000,20000])
new_price=price*0.5
print(new_price)
# Out:
# [ 65000.  70000. 125000.  10000.]
