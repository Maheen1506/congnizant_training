# %%
class Car:
    colour="White"
    name="Toyota"
    model="2021"
car1=Car
print(car1.colour,car1.name,car1.model)
# Out:
# White Toyota 2021

# %%
class Employee:
    def __init__(self,name,age):
     self.name = name
     self.age = age
emp1 = Employee("Maheen", 20)
print(emp1.name)
print(emp1.age)
# Out:
# Maheen
# 20
