# %%
import pandas as pd
marks=pd.Series([10,20,30,40])
print(marks)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
marks=pd.Series()
print(marks)
# Out:
# Series([], dtype: object)

# %%
import pandas as pd
marks=pd.Series([10,20,30,40],)
print(marks[1])
# Out:
# 20

# %%
student_name=pd.Series(["rani","raju","rahul"])
print(student_name)
# Out:
# 0     rani
# 1     raju
# 2    rahul
# dtype: object

# %%
Employee_salary=pd.Series([10000,20000,30000,40000])
print(Employee_salary)
# Out:
# 0    10000
# 1    20000
# 2    30000
# 3    40000
# dtype: int64

# %%
t=pd.Series((15,46,78,90,89))
print(t)
# Out:
# 0    15
# 1    46
# 2    78
# 3    90
# 4    89
# dtype: int64

# %%
student=pd.Series({"Rani":80,"Rahul":78,"Raju":91})
print(student)
# Out:
# Rani     80
# Rahul    78
# Raju     91
# dtype: int64

# %%
i=pd.Series([120,200,100,390])
print(i)
# Out:
# 0    120
# 1    200
# 2    100
# 3    390
# dtype: int64

# %% [markdown]
# #indexing,datatype,size,values

# %%
s=pd.Series([100,200,250],index=["a","b","c"])
print(s)
# Out:
# a    100
# b    200
# c    250
# dtype: int64

# %%
w=pd.Series((20,30,40),index=["A","B","C"])
print(w)
# Out:
# A    20
# B    30
# C    40
# dtype: int64

# %%
w=pd.Series((20,30,40),index=["A","B","C"])
print(w["B"])
# Out:
# 30

# %%
w=pd.Series((20,30,40),index=["A","B","C"])
print(w[["B","A"]])
# Out:
# B    30
# A    20
# dtype: int64

# %%
w=pd.Series((20,30,40),index=["A","B","C"])
print(w.values)
# Out:
# [20 30 40]

# %%
print(w.index)
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
print(w.dtype)
# Out:
# int64

# %%
print(w.size)
# Out:
# 3

# %%
s=pd.Series([200,30,400,590])
print(s+10)
print(s*2)
print(s-2)
print(s/3)
# Out:
# 0    210
# 1     40
# 2    410
# 3    600
# dtype: int64
# 0     400
# 1      60
# 2     800
# 3    1180
# dtype: int64
# 0    198
# 1     28
# 2    398
# 3    588
# dtype: int64
# 0     66.666667
# 1     10.000000
# 2    133.333333
# 3    196.666667
# dtype: float64
