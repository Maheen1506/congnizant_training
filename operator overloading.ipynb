# %%
print(11+12)
print("Maheen"+" "+"Fathima")
# Out:
# 23
# Maheen Fathima

# %%
class Student:
    def __init__(self,marks):
        self.marks=marks

    def __add__(self,others):
        return self.marks+others.marks
s1=Student(80)
s2=Student(90)
print(s1+s2)
# Out:
# 170
