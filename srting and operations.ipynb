# %%
name="Maheen"
emailid="fathima@gamail.com"
print(name)
print(emailid)
# Out:
# Maheen
# fathima@gamail.com

# %%
city="karimnnagar"
print(city[0])
# Out:
# k

# %%
city="karimnnagar"
print(city[-1])
# Out:
# r

# %%
city="karimnnagar"
print(city[1:5])
# Out:
# arim

# %%
city="karimnnagar"
print(len(city))
# Out:
# 11

# %%
firstname="Maheen"
secondname="Fathima"
print(firstname+" "+secondname)
# Out:
# Maheen Fathima

# %%
s="hello"
print(s*3)
# Out:
# hellohellohello

# %%
print("hello"*3)
# Out:
# hellohellohello

# %%
print("hello" * 3)
# Out:
# hellohellohello

# %%
name="maheen"
print(name.upper())
# Out:
# MAHEEN

# %%
name="MAHEEN"
print(name.lower())
# Out:
# maheen

# %%
m="I like Mango"
print(m.replace("Mango","Apple"))
# Out:
# I like Apple

# %%
s="mango apple"
print(s.find("apple"))
# Out:
# 6

# %% [raw]
# name=input("Enter the name:")
# print("welcome",name)

# %%
name=input("Enter the name:")
print("welcome",name)
# Out:
# Enter the name: maheen
# welcome maheen

# %%
s="123456"
print(s[::-1])
# Out:
# 654321

# %%
a=input("Enter the number:")
b=input("Enter the number:")
print(a+b)
# Out:
# Enter the number: 10
# Enter the number: 34
# 1034
